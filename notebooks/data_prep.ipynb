# %%
# !pip install pandas numpy scikit-learn matplotlib mplsoccer statsbombpy
# Out:
# Requirement already satisfied: pandas in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (2.3.3)
# Requirement already satisfied: numpy in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (2.4.0)
# Requirement already satisfied: scikit-learn in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (1.8.0)
# Requirement already satisfied: matplotlib in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (3.10.8)
# Requirement already satisfied: mplsoccer in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (1.6.1)
# Requirement already satisfied: statsbombpy in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (4.61.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (12.1.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: requests in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from mplsoccer) (2.32.5)
# Requirement already satisfied: seaborn in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from mplsoccer) (0.13.2)
# Requirement already satisfied: requests-cache in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from statsbombpy) (1.2.1)
# Requirement already satisfied: inflect in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from statsbombpy) (7.5.0)
# Requirement already satisfied: six>=1.5 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Requirement already satisfied: more_itertools>=8.5.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from inflect->statsbombpy) (10.8.0)
# Requirement already satisfied: typeguard>=4.0.1 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from inflect->statsbombpy) (4.4.4)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (4.15.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests->mplsoccer) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests->mplsoccer) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests->mplsoccer) (2.6.2)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests->mplsoccer) (2025.11.12)
# Requirement already satisfied: attrs>=21.2 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests-cache->statsbombpy) (25.4.0)
# Requirement already satisfied: cattrs>=22.2 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests-cache->statsbombpy) (25.3.0)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests-cache->statsbombpy) (4.5.1)
# Requirement already satisfied: url-normalize>=1.4 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests-cache->statsbombpy) (2.2.1)

# %%
import numpy as np
import pandas as pd

from statsbombpy import sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.calibration import calibration_curve

import matplotlib.pyplot as plt
from mplsoccer import Pitch

# %%
comps = sb.competitions()  # all open competitions/seasons available
comps.columns
# Out:
# Index(['competition_id', 'season_id', 'country_name', 'competition_name',
#        'competition_gender', 'competition_youth', 'competition_international',
#        'season_name', 'match_updated', 'match_updated_360',
#        'match_available_360', 'match_available'],
#       dtype='object')

# %%
comps.head()
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-09-28T20:46:38.893391  2025-07-06T04:26:07.636270
# 1   2015/2016  2024-05-19T11:11:14.192381                        None
# 2        2023  2024-09-28T01:57:35.846538                        None
# 3   2018/2019  2025-05-08T15:10:50.835274     2021-06-13T16:17:31.694
# 4   2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
#
#           match_available_360             match_available
# 0  2025-07-06T04:26:07.636270  2024-09-28T20:46:38.893391
# 1                        None  2024-05-19T11:11:14.192381
# 2                        None  2024-09-28T01:57:35.846538
# 3                        None  2025-05-08T15:10:50.835274
# 4                        None  2024-02-13T02:35:28.134882

# %%
laliga = comps[comps['competition_name'].str.contains('La Liga', case=False, na=False)]
laliga[['competition_id', 'season_id', 'season_name']].drop_duplicates().head(10)
# Out:
#     competition_id  season_id season_name
# 38              11         90   2020/2021
# 39              11         42   2019/2020
# 40              11          4   2018/2019
# 41              11          1   2017/2018
# 42              11          2   2016/2017
# 43              11         27   2015/2016
# 44              11         26   2014/2015
# 45              11         25   2013/2014
# 46              11         24   2012/2013
# 47              11         23   2011/2012

# %%
season_match_counts = []
for _, row in laliga.drop_duplicates(subset=['competition_id', 'season_id']).iterrows():
    matches = sb.matches(competition_id=row['competition_id'], season_id=row['season_id'])
    season_match_counts.append({
        "competition_id": row["competition_id"],
        "season_id": row["season_id"],
        "season_name": row["season_name"],
        "n_matches": len(matches)
    })

season_match_counts = pd.DataFrame(season_match_counts).sort_values("n_matches", ascending=False)
season_match_counts.head(10)
# Out:
#     competition_id  season_id season_name  n_matches
# 5               11         27   2015/2016        380
# 6               11         26   2014/2015         38
# 9               11         23   2011/2012         37
# 3               11          1   2017/2018         36
# 11              11         21   2009/2010         35
# 0               11         90   2020/2021         35
# 2               11          4   2018/2019         34
# 4               11          2   2016/2017         34
# 1               11         42   2019/2020         33
# 10              11         22   2010/2011         33

# %%
best = season_match_counts.iloc[0]
competition_id = int(best["competition_id"])
season_id = int(best["season_id"])
best
# Out:
# competition_id           11
# season_id                27
# season_name       2015/2016
# n_matches               380
# Name: 5, dtype: object

# %%
matches = sb.matches(competition_id=competition_id, season_id=season_id)
match_ids = matches['match_id'].tolist()
len(match_ids), match_ids[:3]
# Out:
# (380, [3825848, 3825895, 3825894])

# %%
events_list = []
for mid in match_ids:
    ev = sb.events(match_id=mid)
    ev['match_id'] = mid
    events_list.append(ev)

events = pd.concat(events_list, ignore_index=True)
events.shape
# Out:
# (1295354, 117)

# %%
shots = events[events['type'] == 'Shot'].copy()
shots.shape
# Out:
# (9168, 117)

# %%
shots['is_goal'] = (shots['shot_outcome'] == 'Goal').astype(int)
shots['shot_outcome'].value_counts().head()
# Out:
# shot_outcome
# Off T      2981
# Saved      2216
# Blocked    2081
# Goal       1014
# Wayward     599
# Name: count, dtype: int64

# %%
# StatsBomb data includes shot_type like 'Penalty'
shots = shots[shots['shot_type'] != 'Penalty'].copy()
shots.shape
# Out:
# (9071, 118)

# %% [markdown]
# # Feature Engineering: Distance and Angle

# %%
# location is usually like [x, y]
shots['x'] = shots['location'].apply(lambda v: v[0] if isinstance(v, (list, tuple)) else np.nan)
shots['y'] = shots['location'].apply(lambda v: v[1] if isinstance(v, (list, tuple)) else np.nan)
shots = shots.dropna(subset=['x', 'y']).copy()

# %%
GOAL_X = 120
GOAL_Y = 40

shots['distance'] = np.sqrt((GOAL_X - shots['x'])**2 + (GOAL_Y - shots['y'])**2)

# %%
LEFT_POST_Y = 36
RIGHT_POST_Y = 44

# vectors from shot to each post
dx = GOAL_X - shots['x']
dy_left = LEFT_POST_Y - shots['y']
dy_right = RIGHT_POST_Y - shots['y']

angle = np.abs(np.arctan2(dy_right, dx) - np.arctan2(dy_left, dx))
shots['angle'] = angle

# %%
shots[['x','y','distance','angle','is_goal']].describe()
# Out:
#                  x            y     distance        angle      is_goal
# count  9071.000000  9071.000000  9071.000000  9071.000000  9071.000000
# mean    103.763764    39.670136    19.121925     0.440915     0.104178
# std       8.705619    10.092545     8.701275     0.274636     0.305508
# min      50.300000     0.700000     0.632456     0.005230     0.000000
# 25%      97.500000    32.100000    12.138781     0.263102     0.000000
# 50%     105.200000    39.700000    18.388312     0.341197     0.000000
# 75%     110.700000    47.000000    25.329232     0.539195     0.000000
# max     120.000000    78.800000    74.867416     3.141593     1.000000
