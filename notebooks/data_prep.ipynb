# %%
# !pip install pandas numpy scikit-learn matplotlib mplsoccer statsbombpy
# Out:
# Collecting pandas
#   Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl.metadata (19 kB)
# Collecting numpy
#   Downloading numpy-2.4.0-cp314-cp314-win_amd64.whl.metadata (6.6 kB)
# Collecting scikit-learn
#   Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl.metadata (11 kB)
# Collecting matplotlib
#   Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl.metadata (52 kB)
# Collecting mplsoccer
#   Using cached mplsoccer-1.6.1-py3-none-any.whl.metadata (4.8 kB)
# Collecting statsbombpy
#   Using cached statsbombpy-1.16.0-py3-none-any.whl.metadata (63 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from pandas) (2.9.0.post0)
# Collecting pytz>=2020.1 (from pandas)
#   Downloading pytz-2025.2-py2.py3-none-any.whl.metadata (22 kB)
# Collecting tzdata>=2022.7 (from pandas)
#   Downloading tzdata-2025.3-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting scipy>=1.10.0 (from scikit-learn)
#   Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl.metadata (60 kB)
# Collecting joblib>=1.3.0 (from scikit-learn)
#   Downloading joblib-1.5.3-py3-none-any.whl.metadata (5.5 kB)
# Collecting threadpoolctl>=3.2.0 (from scikit-learn)
#   Downloading threadpoolctl-3.6.0-py3-none-any.whl.metadata (13 kB)
# Collecting contourpy>=1.0.1 (from matplotlib)
#   Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl.metadata (5.5 kB)
# Collecting cycler>=0.10 (from matplotlib)
#   Downloading cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# Collecting fonttools>=4.22.0 (from matplotlib)
#   Downloading fonttools-4.61.1-cp314-cp314-win_amd64.whl.metadata (116 kB)
# Collecting kiwisolver>=1.3.1 (from matplotlib)
#   Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl.metadata (6.4 kB)
# Requirement already satisfied: packaging>=20.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from matplotlib) (25.0)
# Collecting pillow>=8 (from matplotlib)
#   Downloading pillow-12.1.0-cp314-cp314-win_amd64.whl.metadata (9.0 kB)
# Collecting pyparsing>=3 (from matplotlib)
#   Downloading pyparsing-3.3.1-py3-none-any.whl.metadata (5.6 kB)
# Collecting requests (from mplsoccer)
#   Downloading requests-2.32.5-py3-none-any.whl.metadata (4.9 kB)
# Collecting seaborn (from mplsoccer)
#   Downloading seaborn-0.13.2-py3-none-any.whl.metadata (5.4 kB)
# Collecting requests-cache (from statsbombpy)
#   Using cached requests_cache-1.2.1-py3-none-any.whl.metadata (9.9 kB)
# Collecting inflect (from statsbombpy)
#   Using cached inflect-7.5.0-py3-none-any.whl.metadata (24 kB)
# Requirement already satisfied: six>=1.5 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Collecting more_itertools>=8.5.0 (from inflect->statsbombpy)
#   Downloading more_itertools-10.8.0-py3-none-any.whl.metadata (39 kB)
# Collecting typeguard>=4.0.1 (from inflect->statsbombpy)
#   Using cached typeguard-4.4.4-py3-none-any.whl.metadata (3.3 kB)
# Requirement already satisfied: typing_extensions>=4.14.0 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from typeguard>=4.0.1->inflect->statsbombpy) (4.15.0)
# Collecting charset_normalizer<4,>=2 (from requests->mplsoccer)
#   Downloading charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl.metadata (38 kB)
# Collecting idna<4,>=2.5 (from requests->mplsoccer)
#   Downloading idna-3.11-py3-none-any.whl.metadata (8.4 kB)
# Collecting urllib3<3,>=1.21.1 (from requests->mplsoccer)
#   Downloading urllib3-2.6.2-py3-none-any.whl.metadata (6.6 kB)
# Collecting certifi>=2017.4.17 (from requests->mplsoccer)
#   Downloading certifi-2025.11.12-py3-none-any.whl.metadata (2.5 kB)
# Collecting attrs>=21.2 (from requests-cache->statsbombpy)
#   Using cached attrs-25.4.0-py3-none-any.whl.metadata (10 kB)
# Collecting cattrs>=22.2 (from requests-cache->statsbombpy)
#   Using cached cattrs-25.3.0-py3-none-any.whl.metadata (8.4 kB)
# Requirement already satisfied: platformdirs>=2.5 in c:\users\jeet\anaconda3\envs\myenv\lib\site-packages (from requests-cache->statsbombpy) (4.5.1)
# Collecting url-normalize>=1.4 (from requests-cache->statsbombpy)
#   Using cached url_normalize-2.2.1-py3-none-any.whl.metadata (5.6 kB)
# Downloading pandas-2.3.3-cp314-cp314-win_amd64.whl (11.1 MB)
#    ---------------------------------------- 0.0/11.1 MB ? eta -:--:--
#    ------------------ --------------------- 5.2/11.1 MB 26.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 10.0/11.1 MB 24.5 MB/s eta 0:00:01
#    ---------------------------------------- 11.1/11.1 MB 21.4 MB/s  0:00:00
# Downloading numpy-2.4.0-cp314-cp314-win_amd64.whl (12.4 MB)
#    ---------------------------------------- 0.0/12.4 MB ? eta -:--:--
#    ------------------ --------------------- 5.8/12.4 MB 28.6 MB/s eta 0:00:01
#    ------------------------------------ --- 11.3/12.4 MB 28.0 MB/s eta 0:00:01
#    ---------------------------------------- 12.4/12.4 MB 25.8 MB/s  0:00:00
# Downloading scikit_learn-1.8.0-cp314-cp314-win_amd64.whl (8.1 MB)
#    ---------------------------------------- 0.0/8.1 MB ? eta -:--:--
#    ----------------------------- ---------- 6.0/8.1 MB 29.6 MB/s eta 0:00:01
#    ---------------------------------------- 8.1/8.1 MB 27.4 MB/s  0:00:00
# Downloading matplotlib-3.10.8-cp314-cp314-win_amd64.whl (8.3 MB)
#    ---------------------------------------- 0.0/8.3 MB ? eta -:--:--
#    ------------------------------ --------- 6.3/8.3 MB 30.1 MB/s eta 0:00:01
#    ---------------------------------------- 8.3/8.3 MB 28.0 MB/s  0:00:00
# Using cached mplsoccer-1.6.1-py3-none-any.whl (88 kB)
# Using cached statsbombpy-1.16.0-py3-none-any.whl (16 kB)
# Downloading contourpy-1.3.3-cp314-cp314-win_amd64.whl (232 kB)
# Downloading cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Downloading fonttools-4.61.1-cp314-cp314-win_amd64.whl (2.3 MB)
#    ---------------------------------------- 0.0/2.3 MB ? eta -:--:--
#    ---------------------------------------- 2.3/2.3 MB 18.4 MB/s  0:00:00
# Downloading joblib-1.5.3-py3-none-any.whl (309 kB)
# Downloading kiwisolver-1.4.9-cp314-cp314-win_amd64.whl (75 kB)
# Downloading pillow-12.1.0-cp314-cp314-win_amd64.whl (7.2 MB)
#    ---------------------------------------- 0.0/7.2 MB ? eta -:--:--
#    ------------------------ --------------- 4.5/7.2 MB 22.5 MB/s eta 0:00:01
#    ---------------------------------------- 7.2/7.2 MB 23.6 MB/s  0:00:00
# Downloading pyparsing-3.3.1-py3-none-any.whl (121 kB)
# Downloading pytz-2025.2-py2.py3-none-any.whl (509 kB)
# Downloading scipy-1.16.3-cp314-cp314-win_amd64.whl (39.4 MB)
#    ---------------------------------------- 0.0/39.4 MB ? eta -:--:--
#    ------- -------------------------------- 7.9/39.4 MB 39.4 MB/s eta 0:00:01
#    ---------------- ----------------------- 16.3/39.4 MB 39.7 MB/s eta 0:00:01
#    ------------------------- -------------- 24.6/39.4 MB 40.1 MB/s eta 0:00:01
#    --------------------------------- ------ 32.8/39.4 MB 40.1 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.4 MB 40.0 MB/s eta 0:00:01
#    ---------------------------------------- 39.4/39.4 MB 36.5 MB/s  0:00:01
# Downloading threadpoolctl-3.6.0-py3-none-any.whl (18 kB)
# Downloading tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# Using cached inflect-7.5.0-py3-none-any.whl (35 kB)
# Downloading more_itertools-10.8.0-py3-none-any.whl (69 kB)
# Using cached typeguard-4.4.4-py3-none-any.whl (34 kB)
# Downloading requests-2.32.5-py3-none-any.whl (64 kB)
# Downloading charset_normalizer-3.4.4-cp314-cp314-win_amd64.whl (107 kB)
# Downloading idna-3.11-py3-none-any.whl (71 kB)
# Downloading urllib3-2.6.2-py3-none-any.whl (131 kB)
# Downloading certifi-2025.11.12-py3-none-any.whl (159 kB)
# Using cached requests_cache-1.2.1-py3-none-any.whl (61 kB)
# Using cached attrs-25.4.0-py3-none-any.whl (67 kB)
# Using cached cattrs-25.3.0-py3-none-any.whl (70 kB)
# Using cached url_normalize-2.2.1-py3-none-any.whl (14 kB)
# Downloading seaborn-0.13.2-py3-none-any.whl (294 kB)
# Installing collected packages: pytz, urllib3, tzdata, typeguard, threadpoolctl, pyparsing, pillow, numpy, more_itertools, kiwisolver, joblib, idna, fonttools, cycler, charset_normalizer, certifi, attrs, url-normalize, scipy, requests, pandas, inflect, contourpy, cattrs, scikit-learn, requests-cache, matplotlib, statsbombpy, seaborn, mplsoccer
#
#    ----------------------------------------  0/30 [pytz]
#    ----------------------------------------  0/30 [pytz]
#    ----------------------------------------  0/30 [pytz]
#    - --------------------------------------  1/30 [urllib3]
#    -- -------------------------------------  2/30 [tzdata]
#    -- -------------------------------------  2/30 [tzdata]
#    -- -------------------------------------  2/30 [tzdata]
#    -- -------------------------------------  2/30 [tzdata]
#    ---- -----------------------------------  3/30 [typeguard]
#    ------ ---------------------------------  5/30 [pyparsing]
#    -------- -------------------------------  6/30 [pillow]
#    -------- -------------------------------  6/30 [pillow]
#    -------- -------------------------------  6/30 [pillow]
#    -------- -------------------------------  6/30 [pillow]
#    -------- -------------------------------  6/30 [pillow]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    --------- ------------------------------  7/30 [numpy]
#    ------------ ---------------------------  9/30 [kiwisolver]
#    ------------- -------------------------- 10/30 [joblib]
#    ------------- -------------------------- 10/30 [joblib]
#    -------------- ------------------------- 11/30 [idna]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ---------------- ----------------------- 12/30 [fonttools]
#    ------------------ --------------------- 14/30 [charset_normalizer]
#    --------------------- ------------------ 16/30 [attrs]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    ------------------------ --------------- 18/30 [scipy]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    -------------------------- ------------- 20/30 [pandas]
#    ----------------------------- ---------- 22/30 [contourpy]
#    ------------------------------ --------- 23/30 [cattrs]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    -------------------------------- ------- 24/30 [scikit-learn]
#    --------------------------------- ------ 25/30 [requests-cache]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ---------------------------------- ----- 26/30 [matplotlib]
#    ------------------------------------- -- 28/30 [seaborn]
#    ------------------------------------- -- 28/30 [seaborn]
#    -------------------------------------- - 29/30 [mplsoccer]
#    ---------------------------------------- 30/30 [mplsoccer]
#
# Successfully installed attrs-25.4.0 cattrs-25.3.0 certifi-2025.11.12 charset_normalizer-3.4.4 contourpy-1.3.3 cycler-0.12.1 fonttools-4.61.1 idna-3.11 inflect-7.5.0 joblib-1.5.3 kiwisolver-1.4.9 matplotlib-3.10.8 more_itertools-10.8.0 mplsoccer-1.6.1 numpy-2.4.0 pandas-2.3.3 pillow-12.1.0 pyparsing-3.3.1 pytz-2025.2 requests-2.32.5 requests-cache-1.2.1 scikit-learn-1.8.0 scipy-1.16.3 seaborn-0.13.2 statsbombpy-1.16.0 threadpoolctl-3.6.0 typeguard-4.4.4 tzdata-2025.3 url-normalize-2.2.1 urllib3-2.6.2

# %%
import numpy as np
import pandas as pd

from statsbombpy import sb
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import log_loss, roc_auc_score
from sklearn.calibration import calibration_curve

import matplotlib.pyplot as plt
from mplsoccer import Pitch

# %%
comps = sb.competitions()  # all open competitions/seasons available
comps.columns
# Out:
# Index(['competition_id', 'season_id', 'country_name', 'competition_name',
#        'competition_gender', 'competition_youth', 'competition_international',
#        'season_name', 'match_updated', 'match_updated_360',
#        'match_available_360', 'match_available'],
#       dtype='object')

# %%
comps.head()
# Out:
#    competition_id  season_id country_name        competition_name  \
# 0               9        281      Germany           1. Bundesliga
# 1               9         27      Germany           1. Bundesliga
# 2            1267        107       Africa  African Cup of Nations
# 3              16          4       Europe        Champions League
# 4              16          1       Europe        Champions League
#
#   competition_gender  competition_youth  competition_international  \
# 0               male              False                      False
# 1               male              False                      False
# 2               male              False                       True
# 3               male              False                      False
# 4               male              False                      False
#
#   season_name               match_updated           match_updated_360  \
# 0   2023/2024  2024-09-28T20:46:38.893391  2025-07-06T04:26:07.636270
# 1   2015/2016  2024-05-19T11:11:14.192381                        None
# 2        2023  2024-09-28T01:57:35.846538                        None
# 3   2018/2019  2025-05-08T15:10:50.835274     2021-06-13T16:17:31.694
# 4   2017/2018  2024-02-13T02:35:28.134882     2021-06-13T16:17:31.694
#
#           match_available_360             match_available
# 0  2025-07-06T04:26:07.636270  2024-09-28T20:46:38.893391
# 1                        None  2024-05-19T11:11:14.192381
# 2                        None  2024-09-28T01:57:35.846538
# 3                        None  2025-05-08T15:10:50.835274
# 4                        None  2024-02-13T02:35:28.134882

# %%
laliga = comps[comps['competition_name'].str.contains('La Liga', case=False, na=False)]
laliga[['competition_id', 'season_id', 'season_name']].drop_duplicates().head(10)
# Out:
#     competition_id  season_id season_name
# 38              11         90   2020/2021
# 39              11         42   2019/2020
# 40              11          4   2018/2019
# 41              11          1   2017/2018
# 42              11          2   2016/2017
# 43              11         27   2015/2016
# 44              11         26   2014/2015
# 45              11         25   2013/2014
# 46              11         24   2012/2013
# 47              11         23   2011/2012

# %%
season_match_counts = []
for _, row in laliga.drop_duplicates(subset=['competition_id', 'season_id']).iterrows():
    matches = sb.matches(competition_id=row['competition_id'], season_id=row['season_id'])
    season_match_counts.append({
        "competition_id": row["competition_id"],
        "season_id": row["season_id"],
        "season_name": row["season_name"],
        "n_matches": len(matches)
    })

season_match_counts = pd.DataFrame(season_match_counts).sort_values("n_matches", ascending=False)
season_match_counts.head(10)
# Out:
#     competition_id  season_id season_name  n_matches
# 5               11         27   2015/2016        380
# 6               11         26   2014/2015         38
# 9               11         23   2011/2012         37
# 3               11          1   2017/2018         36
# 11              11         21   2009/2010         35
# 0               11         90   2020/2021         35
# 2               11          4   2018/2019         34
# 4               11          2   2016/2017         34
# 1               11         42   2019/2020         33
# 10              11         22   2010/2011         33

# %%
best = season_match_counts.iloc[0]
competition_id = int(best["competition_id"])
season_id = int(best["season_id"])
best
# Out:
# competition_id           11
# season_id                27
# season_name       2015/2016
# n_matches               380
# Name: 5, dtype: object

# %%
matches = sb.matches(competition_id=competition_id, season_id=season_id)
match_ids = matches['match_id'].tolist()
len(match_ids), match_ids[:3]
# Out:
# (380, [3825848, 3825895, 3825894])

# %%
events_list = []
for mid in match_ids:
    ev = sb.events(match_id=mid)
    ev['match_id'] = mid
    events_list.append(ev)

events = pd.concat(events_list, ignore_index=True)
events.shape
